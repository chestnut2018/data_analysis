# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#常见函数" data-toc-modified-id="常见函数-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>常见函数</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#一元函数" data-toc-modified-id="一元函数-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>一元函数</a></span></li><li><span><a href="#二元函数" data-toc-modified-id="二元函数-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>二元函数</a></span><ul class="toc-item"><li><span><a href="#add加-subtract减--multiply乘-devide除" data-toc-modified-id="add加-subtract减--multiply乘-devide除-1.0.2.1"><span class="toc-item-num">1.0.2.1&nbsp;&nbsp;</span>add加 subtract减  multiply乘 devide除</a></span></li></ul></li><li><span><a href="#meshgrid函数" data-toc-modified-id="meshgrid函数-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>meshgrid函数</a></span></li><li><span><a href="#column_stack" data-toc-modified-id="column_stack-1.0.4"><span class="toc-item-num">1.0.4&nbsp;&nbsp;</span>column_stack</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # 常见函数

# %% [markdown]
# ### 一元函数

# %%
import numpy as np

# %%
np.sqrt(np.array([1,2,3]),dtype=np.float64) #开方
# Out:
# array([1.        , 1.41421356, 1.73205081])

# %%
a1= np.random.randint(-15,-2,(4,3))
a1
# Out:
# array([[-12,  -5,  -3],
#        [ -3, -10,  -8],
#        [-10, -14, -11],
#        [-12, -15, -13]])

# %%
np.abs(a1) #绝对值
# Out:
# array([[12,  5,  3],
#        [ 3, 10,  8],
#        [10, 14, 11],
#        [12, 15, 13]])

# %%
np.exp(a1) #返回指数，exp(x)=e^x  例如exp(logx)=e^(logx)=x
# Out:
# array([[6.14421235e-06, 6.73794700e-03, 4.97870684e-02],
#        [4.97870684e-02, 4.53999298e-05, 3.35462628e-04],
#        [4.53999298e-05, 8.31528719e-07, 1.67017008e-05],
#        [6.14421235e-06, 3.05902321e-07, 2.26032941e-06]])

# %%
np.random.normal(3,1.3,(6,4))
# Out:
# array([[2.42385192, 3.24141787, 2.0062794 , 3.83786059],
#        [3.60134521, 1.84384069, 5.02651155, 3.68087676],
#        [1.96239447, 3.48334142, 3.42342334, 4.0192156 ],
#        [2.36330789, 2.68338299, 2.60239818, 0.78867683],
#        [2.12246754, 4.49204282, 5.25181395, 3.46965772],
#        [5.3667565 , 5.08297535, 1.3668789 , 3.50630854]])

# %%
a2 = np.random.normal(3,1.3,(6,4))
a2
# Out:
# array([[2.2765649 , 3.24090264, 3.58266879, 4.88571032],
#        [2.31403263, 2.99765336, 3.91694747, 2.11852491],
#        [4.01164208, 3.05061284, 2.54095662, 4.41018164],
#        [4.92881209, 4.25714177, 1.64902309, 3.82614701],
#        [1.97776853, 3.70326126, 2.82030274, 3.75001296],
#        [1.87559177, 2.62824148, 3.34011033, 6.59201515]])

# %%
np.floor(a2) #向下取整(舍弃小数)
# Out:
# array([[2., 3., 3., 4.],
#        [2., 2., 3., 2.],
#        [4., 3., 2., 4.],
#        [4., 4., 1., 3.],
#        [1., 3., 2., 3.],
#        [1., 2., 3., 6.]])

# %%
np.ceil(a2) #向上取整(进1)
# Out:
# array([[3., 4., 4., 5.],
#        [3., 3., 4., 3.],
#        [5., 4., 3., 5.],
#        [5., 5., 2., 4.],
#        [2., 4., 3., 4.],
#        [2., 3., 4., 7.]])

# %%
np.random.normal(3.0,1.3,(6,8)) #正态分布
# Out:
# array([[2.88086327, 1.20358026, 2.64224855, 3.24577521, 4.18677066,
#         3.18980762, 4.75682666, 1.866514  ],
#        [3.51913584, 5.12372511, 3.41565914, 2.3377939 , 2.58961934,
#         2.74761773, 4.65432513, 4.69599587],
#        [2.10947309, 1.42889673, 3.87432807, 2.78872544, 3.52534791,
#         1.51370868, 2.32940937, 2.28289395],
#        [3.22701455, 0.82381012, 2.25503542, 1.48651361, 2.59790808,
#         3.10666674, 1.72772565, 2.75342308],
#        [2.13530345, 3.66062053, 3.17821689, 3.92165142, 3.09057356,
#         1.18777669, 3.87206205, 3.22565897],
#        [4.0131968 , 2.80142192, 2.46310769, 3.00169942, 2.63248041,
#         2.176832  , 4.85780551, 3.25228375]])

# %%
np.sign([1,-3,-4,6,8]) #符号函数，获得元素的正负号
# Out:
# array([ 1, -1, -1,  1,  1])

# %% [markdown]
# ### 二元函数

# %%
a3 = np.random.randint(6,16,8)
a4 = np.random.randint(5,10,8)
a3,a4
# Out:
# (array([15, 10,  7, 11,  6,  6, 14, 15]), array([8, 9, 6, 8, 7, 7, 7, 8]))

# %%
np.maximum(a3,a4)
# Out:
# array([15, 10,  7, 11,  7,  7, 14, 15])

# %%
np.minimum(a3,a4)
# Out:
# array([8, 9, 6, 8, 6, 6, 7, 8])

# %%
#与max,min 不一样
#没有设置轴的话， 返回整个数组中的最大/最小值
a5 = np.random.randint(-2,9,(3,4))
a5
# Out:
# array([[ 5, -1,  6,  7],
#        [ 8,  6,  7,  8],
#        [ 3,  5,  1, -2]])

# %%
np.max(a5)
# Out:
# 8

# %%
np.max(a5, axis=0) #轴设置为0时，返回每一列的最大值，逐行按列
# Out:
# array([8, 6, 7, 8])

# %%
np.min(a5, axis=1) #轴设置为1时，返回每一行的最小值，逐列按行
# Out:
# array([-1,  6, -2])

# %% [markdown]
# #### add加 subtract减  multiply乘 devide除

# %%
a5 = np.random.randint(2,9,(3,4))
a6 = np.random.randint(1,12,(3,4))
a5
# Out:
# array([[4, 6, 6, 7],
#        [2, 3, 5, 5],
#        [7, 4, 3, 7]])

# %%
a6
# Out:
# array([[6, 3, 2, 6],
#        [7, 7, 2, 6],
#        [7, 1, 7, 6]])

# %%
np.subtract(a5,a6) #相当于减法-操作符  但意义有区别
# Out:
# array([[ 4,  6, -5, -8],
#        [-6,  6,  0, -4],
#        [-1,  3,  2, -3]])

# %%
np.power(a5,a6) #幂运算
# Out:
# array([[     343,       64,   262144,   177147],
#        [48828125,       64,        4, 60466176],
#        [ 5764801,    32768,        3,   390625]], dtype=int32)

# %%
np.power(3,3)
# Out:
# 27

# %%
a6**2
# Out:
# array([[36,  9,  4, 36],
#        [49, 49,  4, 36],
#        [49,  1, 49, 36]], dtype=int32)

# %%
pow(3,3)
# Out:
# 27

# %%
np.exp(3) #e^3
# Out:
# 20.085536923187668

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### meshgrid函数

# %%
x = y = np.linspace(-2.0,2.0,10)
#fig = plt.figure(0,dpi=140,figsize=(8,8)) #画布：编号，分辨率，大小
fig,axe = plt.subplots(1,2,dpi=120,figsize=(8,4))#一次性创建画布和画框
axe[0].scatter(x,y,c='r',marker='.') #scatter散点图
axe[0].set_title('not have meshgrid')

x1,y1 = np.meshgrid(x,y) #先做笛卡尔积
axe[1].scatter(x1,y1,c='b',marker='D')
axe[1].set_title('have meshgrid')
plt.show()

# %%
y1,x1

# %%
def fun(x,y):
    return x*np.exp((-x**2)-(y**2))

# %%
x = y = np.linspace(-2.0, 2.0, 500)
X, Y = np.meshgrid(x, y)
Z=fun(X,Y)

# %%
fig,axe = plt.subplots(2,2,dpi=120,figsize=(12,10))
axe[0,0].imshow(Z)
axe[0,1].imshow(Z,cmap = plt.cm.gray)
axe[1,0].imshow(Z,cmap=plt.cm.cool)
axe[1,1].imshow(Z,cmap=plt.cm.hot)

# %%
# ?np.where

# %%
a7 = 5
np.where([type(a7)==int],'是整数','是小数')[0]
# Out:
# '是整数'

# %%
np.random.seed(4)
a8=np.random.randint(4,16,4)
a8
# Out:
# array([14, 11,  9,  5])

# %%
bool = a8>10
bool
# Out:
# array([ True,  True, False, False])

# %%
a8[bool]
# Out:
# array([14, 11])

# %%
np.where(bool,[1,1,1,1],[0,0,0,0]) #true返回第一个列表的相应位置，false返回第二个列表
# Out:
# array([1, 1, 0, 0])

# %% [markdown]
# ### column_stack

# %%
#标准正态分布，是从标准正态分布中返回一个或多个样本值。 
b1=np.random.randn(4)
b2=np.random.randn(4)
b3=np.column_stack([np.random.randint(3,32,4) for k in range(4)])

# %%
#一维数组与一维数组通过column_stack进行拼接，这两个数组的长度必须相同
#一维数组与二维数组通过column_stack进行拼接，这两个数组的长度必须相同

# %%
b1,b2,b3
# Out:
# (array([ 0.72723587, -1.00972148,  0.25336518,  0.76826876]),
#  array([ 1.23722502, -1.64560644,  1.21713355, -0.42229827]),
#  array([[ 9, 24, 29, 22],
#         [27, 11, 26, 13],
#         [ 5, 20,  3, 16],
#         [17,  5, 11,  4]]))

# %%
np.column_stack((b1,b2))#一维数组和一维数组会拼成二维数组,[b1,b2]或者(b1,b2)
# Out:
# array([[ 0.72723587,  1.23722502],
#        [-1.00972148, -1.64560644],
#        [ 0.25336518,  1.21713355],
#        [ 0.76826876, -0.42229827]])

# %%
np.column_stack([b1,b3])#一维数组的每个元素添加到二维数组的每行的首或尾处
# Out:
# array([[ 0.72723587,  9.        , 24.        , 29.        , 22.        ],
#        [-1.00972148, 27.        , 11.        , 26.        , 13.        ],
#        [ 0.25336518,  5.        , 20.        ,  3.        , 16.        ],
#        [ 0.76826876, 17.        ,  5.        , 11.        ,  4.        ]])

# %%
#二维数组与二维数组通过column_stack进行拼接，这两个数组的行数必须相同
# Out:
# (4, 4)

# %%
np.random.shuffle(b3) #随机洗牌，只对第一维度洗牌，这里只是行打乱，行内数据不变

# %%
b3
# Out:
# array([[27, 11, 26, 13],
#        [17,  5, 11,  4],
#        [ 5, 20,  3, 16],
#        [ 9, 24, 29, 22]])

# %%
def word_combination_games(positive_nr):
    import numpy as np
    import random
    from functools import reduce
    list1=['我','你','他','她','我们','你们','他们','她们']
    random.shuffle(list1)
    list2=['学习','研究','喜欢','厌恶','专研','抛弃','讨厌','练习']
    random.shuffle(list2)
    list3=['女人','美酒','香烟','金钱','Python','豪车','别墅','奢侈品']
    random.shuffle(list3)
    #创建信息列表并随机打乱
    inf_ar=np.column_stack((np.column_stack((np.array(list1),np.array(list2))),np.array(list3)))#把各列表信息以列的形式合并成二维数组，8行3列
    print(inf_ar)
    inf_ar1=inf_ar.copy()
    np.random.shuffle(inf_ar1)#随机打乱合并后二维数组
    random_ar=[[True if np.random.rand()>=0.5 else False for i in range(3)]for j in range(8)]
    #np.random.rand与np.random.randn一样，都是正态分布，但是rand的随机样本位于[0, 1)之间
     #随机生成用作np.where条件的布尔矩阵。
    a1=np.where(np.array(random_ar),inf_ar,inf_ar1)
    if positive_nr-1>7:
        return '数字太大，超出信息列表长度'
    else: 
        return reduce(lambda x,y:x+y,a1[positive_nr-1])  #positive_nr为结果的索引值，最大索引为7

# %%
 random_ar=[[True if np.random.rand()>=0.5 else False for i in range(3)]for j in range(8)]

# %%
 random_ar
# Out:
# [[True, False, False],
#  [False, False, False],
#  [False, True, False],
#  [True, False, False],
#  [True, True, False],
#  [True, True, False],
#  [True, False, True],
#  [True, True, True]]

# %%
word_combination_games(3)
# Out:
# [['你' '喜欢' '女人']
#  ['我' '抛弃' '豪车']
#  ['他们' '学习' '美酒']
#  ['他' '专研' '奢侈品']
#  ['她们' '研究' '金钱']
#  ['她' '练习' '别墅']
#  ['你们' '厌恶' '香烟']
#  ['我们' '讨厌' 'Python']]
# '你们学习香烟'
